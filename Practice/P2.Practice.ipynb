# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
Path.cwd()
# Out:
# WindowsPath('C:/Users/james/Desktop/Projects/Project2-Team3')

# %%
csvpath = Path("../Project2-Team3/NYPD_Shooting_Incident_Data__Historic_.csv")

historical_data = pd.read_csv(csvpath) 

csvpath1 = Path("../Project2-Team3/NYPD_Shooting_Incident_Data__Year_To_Date_.csv")

ytd_data = pd.read_csv(csvpath1)

# %%
# if u wanted to you could have pulled in files re API as well:
# for YTD...u go to the API section of the website and copy the API in JSON:
# df = pd.read_json("https://data.cityofnewyork.us/resource/5ucz-vwe8.json")
# this method u dont seen an API Key or Teoken. U are jsut taking the URL 
# in JSON format...

# df.head(5)

# %%
import pandas as pd    # needed for API work
import os              # needed for API work    
from dotenv import load_dotenv # needed for API work
from sodapy import Socrata # needed for API work
import requests    # not sure if need??????? i think need for url imports
import json

from datetime import datetime, timedelta

# %%
load_dotenv()
# Out:
# True

# %%
load_dotenv()                        
api_key = os.getenv("NYC_OPENDATA_PUBLIC_KEY")
secret_key = os.getenv("NYC_OPENDATA_SECRET_KEY")

url = "https://data.cityofnewyork.us/resource/5ucz-vwe8.json"

requests.get(url)

response_data = requests.get(url)

#response_content = response_data.content

print(json.dumps(response_data.json(), indent=4))

print(response_content)

# result = get.requests(url, api_key, secret_key)
# print(result)
# Out:
# [
#     {
#         "incident_key": "211362505",
#         "occur_date": "2020-03-21T00:00:00.000",
#         "occur_time": "23:57:00",
#         "boro": "BROOKLYN",
#         "precinct": "79",
#         "jurisdiction_code": "2",
#         "location_desc": "MULTI DWELL - PUBLIC HOUS",
#         "statistical_murder_flag": false,
#         "vic_age_group": "25-44",
#         "vic_sex": "M",
#         "vic_race": "BLACK",
#         "x_coord_cd": "998138",
#         "y_coord_cd": "193910",
#         "latitude": "40.698912245000031",
#         "longitude": "-73.949915843999975",
#         "geocoded_column": {
#             "type": "Point",
#             "coordinates": [
#                 -73.94991584399997,
#                 40.69891224500003
#             ]
#         },
#         ":@computed_region_efsh_h5xi": "17213",
#         ":@computed_region_f5dn_yrer": "69",
#         ":@computed_region_yeji_bk3q": "2",
#         ":@computed_region_92fq_4b7q": "49",
# ...

# %%
# Out:
# '47xtzsos2e0vazowkybkb5ntv'

# %%
secret_key
# Out:
# '378yharlw80wbunvlv93th7j8ghuyyqcif0consw4luxi90n1f'

# %%
historical_data.head(3)
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME      BORO  PRECINCT  JURISDICTION_CODE  \
# 0      74146165  08/14/2010    3:11:00    QUEENS       113                0.0
# 1      66928846  10/17/2009   18:03:00  BROOKLYN        67                0.0
# 2      29114164  05/18/2007   23:00:00  BROOKLYN        75                0.0
#
#   LOCATION_DESC  STATISTICAL_MURDER_FLAG PERP_AGE_GROUP PERP_SEX PERP_RACE  \
# 0           NaN                    False            NaN      NaN       NaN
# 1           NaN                     True            NaN      NaN       NaN
# 2           NaN                    False            NaN      NaN       NaN
#
#   VIC_AGE_GROUP VIC_SEX VIC_RACE X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 0         25-44       M    BLACK    1046573     183057  40.668915 -73.775341
# 1         45-64       M    BLACK    1003313     176413  40.650877 -73.931302
# 2         25-44       M    BLACK    1016292     176228  40.650332 -73.884529
#
# ...

# %%
ytd_data.head(3)
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO  PRECINCT  \
# 0     211362505  03/21/2020   23:57:00   BROOKLYN        79
# 1     211671833  04/01/2020   21:40:00      BRONX        44
# 2     214690556  06/26/2020   00:30:00  MANHATTAN        13
#
#    JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 0                  2  MULTI DWELL - PUBLIC HOUS                    False
# 1                  0                        NaN                     True
# 2                  0                        NaN                     True
#
#   PERP_AGE_GROUP PERP_SEX       PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# 0            NaN      NaN             NaN         25-44       M
# 1          45-64        M  WHITE HISPANIC         45-64       M
# 2          25-44        M           BLACK         18-24       M
#
#          VIC_RACE X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 0           BLACK    998,138    193,910  40.698912 -73.949916
# ...

# %%
# count nulls historical

historical_data.isnull().sum()
# Out:
# INCIDENT_KEY                   0
# OCCUR_DATE                     0
# OCCUR_TIME                     0
# BORO                           0
# PRECINCT                       0
# JURISDICTION_CODE              2
# LOCATION_DESC              12361
# STATISTICAL_MURDER_FLAG        0
# PERP_AGE_GROUP              7305
# PERP_SEX                    7271
# PERP_RACE                   7271
# VIC_AGE_GROUP                  0
# VIC_SEX                        0
# VIC_RACE                       0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                       0
# Longitude                      0
# Lon_Lat                        0
# dtype: int64

# %%
# count nulls ytd

ytd_data.isnull().sum()
# Out:
# INCIDENT_KEY                  0
# OCCUR_DATE                    0
# OCCUR_TIME                    0
# BORO                          0
# PRECINCT                      0
# JURISDICTION_CODE             0
# LOCATION_DESC               410
# STATISTICAL_MURDER_FLAG       0
# PERP_AGE_GROUP              407
# PERP_SEX                    407
# PERP_RACE                   407
# VIC_AGE_GROUP                 0
# VIC_SEX                       0
# VIC_RACE                      0
# X_COORD_CD                    0
# Y_COORD_CD                    0
# Latitude                      0
# Longitude                     0
# New Georeferenced Column      0
# dtype: int64
