# %%
# Initial imports
import os
from pathlib import Path
import pandas as pd
from newsapi import NewsApiClient
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/stevencherryii/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
api_key ='c5c492da6d534f529f2d9c386c8f500f'

# %%
newsapi = NewsApiClient(api_key=api_key)

# %%
shooting_headlines = newsapi.get_everything(
    q="Covid" and "NYC Shooting",
    language="en",
    
)

print(f"Total articles about NYC shootings: {shooting_headlines['totalResults']}")


shooting_headlines["articles"]
# Out:
# Total articles about NYC shootings: 216
# [{'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Taylor Romine and Eric Levenson, CNN',
#   'title': 'NYC shooting incidents are nearly double this year compared to last year, NYPD stats show',
#   'description': 'New York City has had nearly double the amount of shooting incidents this year compared to this point last year, statistics from the NYPD show.',
#   'url': 'https://www.cnn.com/2020/09/21/us/new-york-gun-violence/index.html',
#   'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200808163503-01-nypd-patch-file-super-tease.jpg',
#   'publishedAt': '2020-09-21T19:27:36Z',
#   'content': None},
#  {'source': {'id': None, 'name': 'TMZ'},
#   'author': 'TMZ Staff',
#   'title': 'Al Sharpton Urges Voting Over Violence in Wake of Breonna Taylor Case',
#   'description': "Rev. Al Sharpton is disgusted like many over the grand jury indictment in Breonna Taylor's case ... but he wants people to take their rage out by voting instead of turning violent. We got Sharpton Wednesday in NYC, and he was still fuming after the…",
#   'url': 'https://www.tmz.com/2020/09/24/al-sharpton-breonna-taylor-case-indictment-vote-no-violence/',
#   'urlToImage': 'https://imagez.tmz.com/image/31/16by9/2020/09/23/31de65e2c96f43dfb6ca8c33c5af983e_xl.jpg',
#   'publishedAt': '2020-09-24T07:20:45Z',
#   'content': "Rev. Al Sharpton is disgusted like many over the grand jury indictment in Breonna Taylor's case ... but he wants people to take their rage out by voting instead of turning violent.\r\nWe got Sharpton W… [+1355 chars]"},
#  {'source': {'id': None, 'name': 'Theguardian.comartanddesign'},
#   'author': 'Alex Rayner',
#   'title': 'Saunas, sex clubs and street fights: how Sunil Gupta captured global gay life – and Miss UK',
#   'description': 'From the treacherous ‘sex trucks’ of New York to the grim days of Aids and Clause 28 in Britain, Sunil Gupta had a ringside seat at the fight for gay liberation. At last, the Zelig-like photographer is getting his duesSunil Gupta can remember the names the wh…',
#   'url': 'https://amp.theguardian.comartanddesign/2020/sep/30/saunas-sex-clubs-street-fights-sunil-gupta-global-gay-life-miss-uk',
#   'urlToImage': 'https://i.guim.co.uk/img/media/5e4611dcd50ea7445f7852a63b01d10328570ef1/232_276_2768_1661/master/2768.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=55cc9bd475c443104d4d7ad2fe3c8902',
#   'publishedAt': '2020-09-30T14:01:19Z',
#   'content': 'Sunil Gupta can remember the names the white schoolkids called each other when he arrivsunisunil l guptaed in Montreal in the late 1960s, having moved there from Delhi. There were Greeks and Italians… [+8228 chars]'},
#  {'source': {'id': None, 'name': 'TMZ'},
#   'author': 'TMZ Staff',
#   'title': 'Hero Dad Who Shielded Kids in Shooting Fired from Jobs, Says Wife',
#   'description': "The hero father who took a bullet to protect his 3 kids during a frightening shooting at a car dealership is on the mend ... but he's now out of 2 jobs and his kids are still in shock. Anthony Jefferson's wife, Danica Jefferson, tells TMZ ...…",
#   'url': 'https://www.tmz.com/2020/09/25/hero-dad-anthony-jefferson-shielded-children-shooting-dealership-fired/',
#   'urlToImage': 'https://imagez.tmz.com/image/a4/16by9/2020/09/23/a47c5f4a666f41b8aed2d557e867e439_xl.jpg',
#   'publishedAt': '2020-09-25T08:00:58Z',
#   'content': "The hero father who took a bullet to protect his 3 kids during a frightening shooting at a car dealership is on the mend ... but he's now out of 2 jobs and his kids are still in shock.\r\nAnthony Jeffe… [+1168 chars]"},
#  {'source': {'id': 'vice-news', 'name': 'Vice News'},
#   'author': 'Emma Ockerman, Anne Torpey',
#   'title': 'An Ex-Black Panther Convicted of Killing 2 Cops Is Getting Paroled After Almost 50 Years',
#   'description': 'Jalil Muntaqim was hospitalized with COVID-19 earlier this year, but the state blocked his bid for even temporary release.',
#   'url': 'https://www.vice.com/en_us/article/g5pav3/an-ex-black-panther-convicted-of-killing-2-cops-is-getting-paroled-after-almost-50-years',
#   'urlToImage': 'https://video-images.vice.com//articles/5f6cb712f1076200957d41bf/lede/1600967650786-anthony-bottom.jpeg?image-resize-opts=Y3JvcD0weHc6MHhoOzB4dywwLjIwODl4aCZyZXNpemU9MTIwMDoqJnJlc2l6ZT0xMjAwOio',
#   'publishedAt': '2020-09-24T17:23:11Z',
#   'content': 'Jalil Muntaqim, the former Black Panther who was known as Anthony Bottom when he was convicted in the murders of two NYC policemen nearly 50 years ago, is set to be released from prison after an orde… [+3795 chars]'},
#  {'source': {'id': None, 'name': 'Deadline'},
#   'author': 'Mike Fleming',
#   'title': 'Bradley Cooper Sets Carey Mulligan To Play Leonard Bernstein’s Wife Felicia In Netflix Film ‘Maestro’',
#   'description': 'EXCLUSIVE: Bradley Cooper has found his onscreen partner and a new title — Maestro — for the Leonard Bernstein film he will star in and direct for Netflix.\xa0 Carey Mulligan has been cast as Felicia Montealegre Cohn Bernstein, wife of the legendary composer/con…',
#   'url': 'https://deadline.com/2020/09/bradley-cooper-carey-mulligan-leonard-bernstein-wife-felicia-montealegre-cohn-bernstein-netflix-film-maestro-1234581942/',
#   'urlToImage': 'https://deadline.com/wp-content/uploads/2020/09/Felicia-Montealegre-Carey-Mulligan.jpg?w=1000',
#   'publishedAt': '2020-09-22T16:12:39Z',
#   'content': 'EXCLUSIVE: Bradley Cooper has found his onscreen partner and a new title — Maestro — for the Leonard Bernstein film he will star in and direct for Netflix.\xa0 Carey Mulligan has been cast as Felicia Mo… [+2536 chars]'},
#  {'source': {'id': None, 'name': 'Deadline'},
#   'author': 'Erik Pedersen',
#   'title': 'Two Officers Shot In Louisville Amid Breonna Taylor Protests; People Also Take To Streets In LA, NYC, Elsewhere',
#   'description': 'Two Louisville Metro Police officers were shot tonight as protests broke out over the grand jury’s decision not to charge three of the city’s officers involved in the March 13 killing of Breonna Taylor. A spokesman said at a news conference that both officers…',
#   'url': 'https://deadline.com/2020/09/breonna-taylor-kentucky-protests-black-lives-matter-1234583270/',
#   'urlToImage': 'https://deadline.com/wp-content/uploads/2020/09/Louisville-police-shooting.jpg?w=1000',
#   'publishedAt': '2020-09-24T03:01:08Z',
#   'content': 'Two Louisville Metro Police officers were shot tonight as protests broke out in response the grand jury’s decision not to charge three of the city’s officers involved in the March 13 killing of Breon… [+1713 chars]'},
#  {'source': {'id': None, 'name': 'YouTube'},
#   'author': None,
#   'title': 'Dad dives in way of gunfire, shielding children at Bronx car dealership - PIX11 News',
#   'description': '<ol><li>Dad dives in way of gunfire, shielding children at Bronx car dealership\xa0\xa0PIX11 News\r\n</li><li>Caught On Camera: Father Shields Children From Bullets Inside Bronx Car Dealership\xa0\xa0CBS New York\r\n</li><li>Wild video shows moment shots are fired into NYC c…',
#   'url': 'https://www.youtube.com/watch?v=r_ztESGCO5I',
#   'urlToImage': 'https://i.ytimg.com/vi/r_ztESGCO5I/maxresdefault.jpg',
#   'publishedAt': '2020-09-23T10:35:42Z',
#   'content': None},
#  {'source': {'id': None, 'name': 'YouTube'},
#   'author': None,
#   'title': 'Arrest made after mother of 3 killed by bullet while at Queens home - Eyewitness News ABC7NY',
#   'description': "<ol><li>Arrest made after mother of 3 killed by bullet while at Queens home\xa0\xa0Eyewitness News ABC7NY\r\n</li><li>NYPD announces arrest in Queens mom's killing by stray bullet\xa0\xa0Fox News\r\n</li><li>Suspect Arrested In Stray Bullet Shooting That Killed Mother Of 3 B…",
#   'url': 'https://www.youtube.com/watch?v=lA4Nywk5O4E',
#   'urlToImage': 'https://i.ytimg.com/vi/lA4Nywk5O4E/hqdefault.jpg',
#   'publishedAt': '2020-10-03T23:13:48Z',
#   'content': None},
#  {'source': {'id': 'independent', 'name': 'Independent'},
#   'author': 'Via AP news wire',
#   'title': 'Breonna Taylor grand jury decision spurs NYC protests',
#   'description': 'Demonstrators packed a New York City plaza Wednesday night to protest a Kentucky grand jury’s decision not to indict any police officers for the fatal shooting of Breonna Taylor',
#   'url': 'https://www.independent.co.uk/news/breonna-taylor-grand-jury-decision-spurs-nyc-protests-breonna-taylor-grand-jury-demonstrators-nyc-ap-b565782.html',
#   'urlToImage': 'https://static.independent.co.uk/2020/09/24/03/Breonna_Taylor-NYC_Protest_43987.jpg',
#   'publishedAt': '2020-09-24T03:12:10Z',
#   'content': "Demonstrators packed a New York City plaza Wednesday night to protest a Kentucky grand jury's decision not to indict any police officers for the fatal shooting of Breonna Taylor\r\nChanting Say her nam… [+809 chars]"},
#  {'source': {'id': None, 'name': 'HipHopDX'},
#   'author': 'Brandon Caldwell',
#   'title': 'Nas, A$AP Ferg & Fivio Foreign Burn Up NYC Shooting ‘Spicy’ Video',
#   'description': "Washington Heights in NYC became a scene for celebration on Saturday as Nas along with Fivio Foreign and A$AP Ferg took to the streets for the 'Spicy' video shoot.",
#   'url': 'https://hiphopdx.com/news/id.57999/title.nas-aap-ferg-fivio-foreign-burn-up-nyc-shooting-spicy-video',
#   'urlToImage': 'https://static.hiphopdx.com/2020/09/200920-nas-instagram-720x405.jpg',
#   'publishedAt': '2020-09-20T17:30:47Z',
#   'content': 'Nas took over Washington Heights in NYC Saturday (September 19) along with Fivio Foreign and A$AP Ferg for the “Spicy” video shoot.\r\nPresumed to be the next single from the Queensbridge rapper’s rece… [+1328 chars]'},
#  {'source': {'id': None, 'name': 'The Daily Caller'},
#   'author': 'Jake Dima',
#   'title': '15-Year-Old Arrested For Allegedly Gunning Down Two Teens In NYC Drive-By',
#   'description': 'A 15-year-old boy was arrested in connection to a July drive-by shooting that killed two teens while they played basketball in NYC.',
#   'url': 'https://dailycaller.com/2020/09/29/teenager-arrested-drive-by-new-york-city-shooting-basketball/',
#   'urlToImage': 'https://cdn01.dailycaller.com/wp-content/uploads/2020/09/drive-by-e1601404475988.jpg',
#   'publishedAt': '2020-09-29T19:05:22Z',
#   'content': 'A 15-year-old boy was arrested in connection to a July drive-by shooting that killed two teenagers while they played basketball in New York City, according to a Tuesday Fox News report.\r\nThe teen’s a… [+1627 chars]'},
#  {'source': {'id': None, 'name': 'Complex'},
#   'author': 'Joshua Espinoza',
#   'title': 'Calvin Klein Highlights Powerful Young Voices in CK One Campaign',
#   'description': 'The campaign profiles a diverse group of young people from towns and cities all across America, including Baltimore, NYC, El Paso, and Fairbanks, Alaska.',
#   'url': 'https://www.complex.com/style/2020/10/calvin-klein-young-voices-ckone-campaign',
#   'urlToImage': 'https://images.complex.com/complex/images/c_fill,f_auto,g_center,w_1200/fl_lossy,pg_1/ztzjdgkyk01elvtpoqav/calvin-klein-highlights-young-voices-in-ckone-campaign',
#   'publishedAt': '2020-10-09T22:45:40Z',
#   'content': 'Calvin Klein\xa0has taken a unique and particularly refreshing approach for its new\xa0CK One campaign.\r\nInstead of\xa0recruiting celebrities and professional models, the American brand is using the campaign … [+2870 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'SNY',
#   'title': 'The Putback with Ian Begley: Can the Knicks bring CP3 to NYC?',
#   'description': 'Ian Begley and Maurice Peebles tip off the show with some Chris Paul to the Knicks discussion, while Ian reveals what he learned from talking with NBA Draft Prospect RJ Hampton and his shooting coach, 2x NBA Champion Mike Miller.',
#   'url': 'https://sports.yahoo.com/putback-ian-begley-knicks-bring-194503375.html',
#   'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/pbnBjzLJhqyIiGhzgYBimQ--~B/aD0xMDgwO3c9MTkyMDtzbT0xO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/hd/cp-video-transcode/prod/2020-09/16/5f626cc5c485b35026be73a8/5f626ce97e53b500010aa478_1920x1080_FES_v1.jpg',
#   'publishedAt': '2020-09-16T19:45:03Z',
#   'content': 'Ian Begley and Maurice Peebles tip off the show with some Chris Paul to the Knicks discussion, while Ian reveals what he learned from talking with NBA Draft Prospect RJ Hampton and his shooting coach… [+29 chars]'},
#  {'source': {'id': None, 'name': 'Variety'},
#   'author': 'Jem Aswad',
#   'title': 'Sault’s ‘Untitled (Rise)’ Seduces Listeners With Sumptuous R&B, Then Startles With Powerful Messaging: Album Review',
#   'description': 'Somehow, the mysterious British R&B/electronic-ish combo Sault has managed to drop four richly diverse, politically confrontational albums, all of them good and two of them absolutely great, in just 18 months. Their willful anonymity would be annoying or pret…',
#   'url': 'https://variety.com/2020/music/reviews/saults-untitled-rise-album-review-1234775193/',
#   'urlToImage': 'https://pmcvariety.files.wordpress.com/2020/09/untitled-5.jpg?w=1000',
#   'publishedAt': '2020-09-18T20:59:16Z',
#   'content': 'Somehow, the mysterious British R&amp;B/electronic-ish combo Sault has managed to drop four richly diverse, socially confrontational albums, all of them good and two of them absolutely great, in just… [+3481 chars]'},
#  {'source': {'id': None, 'name': 'Daily Mail'},
#   'author': 'By Maxine Shen For Dailymail.com',
#   'title': "West Virginia nurse, 39, who worked on NYC frontlines arrested for 'shooting woman in stomach'",
#   'description': 'Amy Thorn, 39, of Williamson, West Virginia, was arrested and faces malicious wounding charges after she allegedly shot\xa0Jonda Whitt in the abdomen, during an argument Thursday.',
#   'url': 'https://www.dailymail.co.uk/news/article-8827325/West-Virginia-nurse-39-worked-NYC-frontlines-arrested-shooting-woman-stomach.html',
#   'urlToImage': 'https://i.dailymail.co.uk/1s/2020/10/11/01/34241838-0-image-a-32_1602375725914.jpg',
#   'publishedAt': '2020-10-11T00:22:12Z',
#   'content': 'A West Virginia registered nurse who traveled to New York City and Texas to treat coronavirus patients at the height of the pandemic and spoke at the RNC was arrested after allegedly shooting a woman… [+2262 chars]'},
#  {'source': {'id': None, 'name': 'Queerty.com'},
#   'author': 'David Reddish',
#   'title': '17-year-old charged with murder used Grindr to find his victims',
#   'description': 'Accused spree shooter Damarion Degrate now faces formal murder charges in Texas.',
#   'url': 'https://www.queerty.com/17-year-old-charged-murder-used-grindr-find-victims-20201013',
#   'urlToImage': 'https://queerty-prodweb.imgix.net/2020/08/damarion-degrate-1.jpg?&auto=format&auto=compress&crop=faces&fit=crop&w=1024&h=576',
#   'publishedAt': '2020-10-13T21:52:43Z',
#   'content': 'Damarion Degrate mugshot.\r\nProsecutors in Texas have formally charged 17-year-old Damarion Degrate with murder in connection with the shooting of a man he met on Grindr last August.\r\nPolice in Waco o… [+1180 chars]'},
#  {'source': {'id': 'breitbart-news', 'name': 'Breitbart News'},
#   'author': 'AWR Hawkins, \nAWR Hawkins',
#   'title': "Over 3,100 Shooting Victims in Mayor Lightfoot's Chicago this Year",
#   'description': "The Chicago Tribune reports the exact number of shooting victims at 3,132 in Mayor Lori Lightfoot's (D) Chicago thus far in 2020.",
#   'url': 'https://www.breitbart.com/politics/2020/09/28/3100-shooting-victims-mayor-lightfoot-chicago-year/',
#   'urlToImage': 'https://media.breitbart.com/media/2020/09/chicago-police-dept-aug30-2020-crime-scene-shooting-getty-640x335.jpg',
#   'publishedAt': '2020-09-29T00:51:13Z',
#   'content': 'Over 3,100 people have been shot in Mayor Lori Lightfoot’s (D) Chicago thus far in 2020.\r\nThe Chicago Tribunereports the exact number of shooting victims at 3,132, and that includes the fatally wound… [+1336 chars]'},
#  {'source': {'id': None, 'name': 'Canonrumors.com'},
#   'author': 'Canon Rumors',
#   'title': 'Five New Photographers Added to Famed Canon Explorers of Light Program',
#   'description': 'MELVILLE, NY, October 1, 2020\xa0–\xa0Canon U.S.A., Inc., a leader in digital imaging solutions, today announced the addition of five photographers to its famed Explorers of Read more...',
#   'url': 'https://www.canonrumors.com/five-new-photographers-added-to-famed-canon-explorers-of-light-program/',
#   'urlToImage': 'https://www.canonrumors.com/wp-content/uploads/2020/10/explorersoflightnew.png',
#   'publishedAt': '2020-10-02T15:57:12Z',
#   'content': 'MELVILLE, NY, October 1, 2020\xa0\xa0Canon U.S.A., Inc., a leader in digital imaging solutions, today announced the addition of five photographers to its famed Explorers of Light (EOL) program. Lara Jade, … [+6261 chars]'},
#  {'source': {'id': None, 'name': 'Daily Mail'},
#   'author': 'By Sarah Abraham For Dailymail.com',
#   'title': "Kaley Cuoco wraps an 'emotional' last day of filming The Flight Attendant with Zosia Mamet in NYC",
#   'description': 'Kaley Cuoco, 34, wrapped her last day of shooting, The Flight Attendant, on Saturday in NYC. The actress and producer of the series filmed her final scenes and said a bittersweet goodbye',
#   'url': 'https://www.dailymail.co.uk/tvshowbiz/article-8827165/Kaley-Cuoco-wraps-emotional-day-filming-Flight-Attendant-Zosia-Mamet-NYC.html',
#   'urlToImage': 'https://i.dailymail.co.uk/1s/2020/10/11/00/34241570-0-image-a-145_1602372931426.jpg',
#   'publishedAt': '2020-10-11T00:35:23Z',
#   'content': 'Upcoming HBO Max series, The Flight Attendant, has been a passion project for its star and producer, Kaley Cuoco, for almost three years.\xa0\xa0\r\nOn Saturday, Kaley, 34, wrapped her last day of shooting i… [+5059 chars]'}]

# %%
# create sentiment score & store it in df:
text_sentiment = []

for article in shooting_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        text_sentiment.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
    except AttributeError:
        pass

# %%
sentiment
# Out:
# {'neg': 0.115, 'neu': 0.636, 'pos': 0.249, 'compound': 0.7574}

# %%
df=pd.DataFrame(text_sentiment)
df.head()
# Out:
#    compound                  date  negative  neutral  positive  \
# 0   -0.8934  2020-09-24T07:20:45Z     0.253    0.671     0.076
# 1    0.0000  2020-09-30T14:01:19Z     0.000    1.000     0.000
# 2   -0.3400  2020-09-25T08:00:58Z     0.126    0.780     0.094
# 3   -0.8074  2020-09-24T17:23:11Z     0.165    0.835     0.000
# 4    0.3034  2020-09-22T16:12:39Z     0.000    0.938     0.062
#
#                                                 text
# 0  Rev. Al Sharpton is disgusted like many over t...
# 1  Sunil Gupta can remember the names the white s...
# 2  The hero father who took a bullet to protect h...
# 3  Jalil Muntaqim, the former Black Panther who w...
# 4  EXCLUSIVE: Bradley Cooper has found his onscre...

# %%
df
# Out:
#     compound                  date  negative  neutral  positive  \
# 0    -0.8934  2020-09-24T07:20:45Z     0.253    0.671     0.076
# 1     0.0000  2020-09-30T14:01:19Z     0.000    1.000     0.000
# 2    -0.3400  2020-09-25T08:00:58Z     0.126    0.780     0.094
# 3    -0.8074  2020-09-24T17:23:11Z     0.165    0.835     0.000
# 4     0.3034  2020-09-22T16:12:39Z     0.000    0.938     0.062
# 5    -0.7269  2020-09-24T03:01:08Z     0.206    0.726     0.068
# 6     0.0000  2020-09-09T19:47:31Z     0.000    1.000     0.000
# 7    -0.3612  2020-09-24T03:12:10Z     0.143    0.779     0.078
# 8    -0.5574  2020-09-15T21:44:58Z     0.119    0.881     0.000
# 9    -0.8689  2020-09-11T15:20:00Z     0.283    0.615     0.102
# 10   -0.3400  2020-09-20T17:30:47Z     0.066    0.934     0.000
# 11   -0.7351  2020-09-29T19:05:22Z     0.190    0.750     0.060
# 12   -0.0644  2020-09-11T18:00:32Z     0.092    0.846     0.062
# 13    0.0000  2020-10-09T22:45:40Z     0.000    1.000     0.000
# 14   -0.4767  2020-09-11T12:59:14Z     0.077    0.923     0.000
# 15    0.2960  2020-09-16T19:45:03Z     0.000    0.942     0.058
# 16    0.7574  2020-09-18T20:59:16Z     0.115    0.636     0.249
#
#                                                  text
# 0   Rev. Al Sharpton is disgusted like many over t...
# 1   Sunil Gupta can remember the names the white s...
# 2   The hero father who took a bullet to protect h...
# 3   Jalil Muntaqim, the former Black Panther who w...
# 4   EXCLUSIVE: Bradley Cooper has found his onscre...
# 5   Two Louisville Metro Police officers were shot...
# 6   As the city prepares to hold a presidential el...
# 7   Demonstrators packed a New York City plaza Wed...
# 8   New York City police are searching for a man w...
# 9   Every day, another shocking video of a brazen ...
# 10  Nas took over Washington Heights in NYC Saturd...
# 11  A 15-year-old boy was arrested in connection t...
# 12  Most everyones got one. If youve been around f...
# 13  Calvin Klein has taken a unique and particular...
# 14  In our Track by Track feature, artists guide l...
# 15  Ian Begley and Maurice Peebles tip off the sho...
# 16  Somehow, the mysterious British R&amp;B/electr...

# %%
df.describe()
# Out:
#         compound   negative    neutral   positive
# count  17.000000  17.000000  17.000000  17.000000
# mean   -0.283212   0.107941   0.838588   0.053471
# std     0.472184   0.091599   0.128321   0.063133
# min    -0.893400   0.000000   0.615000   0.000000
# 25%    -0.726900   0.000000   0.750000   0.000000
# 50%    -0.340000   0.115000   0.846000   0.060000
# 75%     0.000000   0.165000   0.938000   0.076000
# max     0.757400   0.283000   1.000000   0.249000

# %%
from pynytimes import NYTAPI

# %%
nyt = NYTAPI("AGTGevw2BdpxCUBRjEyFC0ymAVDHVA0e", https=False)

# %%
top_stories = nyt.top_stories(section='science')

# %%
top_stories
# Out:
# [{'section': 'health',
#   'subsection': '',
#   'title': 'Trump May Be Immune to the Coronavirus. But for How Long?',
#   'abstract': 'A unique treatment course may have blunted his body’s production of antibodies, scientists warn.',
#   'url': 'https://www.nytimes.com/2020/10/14/health/coronavirus-trump-antibodies.html',
#   'uri': 'nyt://article/171d6480-d54d-521a-96f4-ebbdf8f62614',
#   'byline': 'By Apoorva Mandavilli',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T19:45:22-04:00',
#   'created_date': '2020-10-14T18:33:33-04:00',
#   'published_date': '2020-10-14T18:33:33-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['your-feed-science',
#    'Antibodies',
#    'White House Coronavirus Outbreak (2020)',
#    'Dexamethasone (Drug)',
#    'Coronavirus (2019-nCoV)',
#    'Steroids',
#    'Presidential Election of 2020'],
#   'org_facet': ['Regeneron Pharmaceuticals Inc'],
#   'per_facet': ['Biden, Joseph R Jr', 'Trump, Donald J'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/14/science/14VIRUS-TRUMP/14VIRUS-TRUMP-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Trump addressed supporters outside the White House on Saturday. He has boasted of his immunity to the virus, but experts are wondering how long the protection may last.',
#     'copyright': 'Doug Mills/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14VIRUS-TRUMP/14VIRUS-TRUMP-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Trump addressed supporters outside the White House on Saturday. He has boasted of his immunity to the virus, but experts are wondering how long the protection may last.',
#     'copyright': 'Doug Mills/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14VIRUS-TRUMP/14VIRUS-TRUMP-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Trump addressed supporters outside the White House on Saturday. He has boasted of his immunity to the virus, but experts are wondering how long the protection may last.',
#     'copyright': 'Doug Mills/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14VIRUS-TRUMP/14VIRUS-TRUMP-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Trump addressed supporters outside the White House on Saturday. He has boasted of his immunity to the virus, but experts are wondering how long the protection may last.',
#     'copyright': 'Doug Mills/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14VIRUS-TRUMP/14VIRUS-TRUMP-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Trump addressed supporters outside the White House on Saturday. He has boasted of his immunity to the virus, but experts are wondering how long the protection may last.',
#     'copyright': 'Doug Mills/The New York Times'}],
#   'short_url': 'https://nyti.ms/2H6ZeAo'},
#  {'section': 'health',
#   'subsection': '',
#   'title': 'Scientists Synthesize Jawbones From Pig Fat',
#   'abstract': 'The bones are among the hardest to replace in the body. A trial of the new technique in humans is about to begin.',
#   'url': 'https://www.nytimes.com/2020/10/14/health/jawbone-stem-cells-pigs.html',
#   'uri': 'nyt://article/381efb44-a82d-527f-a43f-510e95f07261',
#   'byline': 'By Gina Kolata',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T17:40:48-04:00',
#   'created_date': '2020-10-14T15:43:50-04:00',
#   'published_date': '2020-10-14T15:43:50-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Bones',
#    'Animals',
#    'Fat Tissue',
#    'Clinical Trials',
#    'Liposuction',
#    'Jaw (Body Part)',
#    'Pigs',
#    'Stem Cells',
#    'Prostheses'],
#   'org_facet': ['Columbia University',
#    'Science Translational Medicine (Journal)'],
#   'per_facet': ['Vunjak-Novakovic, Gordana'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/14/science/14BONE1/merlin_178528971_a630b79a-0d45-4e15-b7dd-4864c4bb846e-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'An X-ray of a healthy human jawbone. “It is one of the most loaded bones in the human body,” one scientist said.',
#     'copyright': 'D. Roberts/Science Source'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14BONE1/14BONE1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'An X-ray of a healthy human jawbone. “It is one of the most loaded bones in the human body,” one scientist said.',
#     'copyright': 'D. Roberts/Science Source'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14BONE1/14BONE1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'An X-ray of a healthy human jawbone. “It is one of the most loaded bones in the human body,” one scientist said.',
#     'copyright': 'D. Roberts/Science Source'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14BONE1/14BONE1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'An X-ray of a healthy human jawbone. “It is one of the most loaded bones in the human body,” one scientist said.',
#     'copyright': 'D. Roberts/Science Source'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14BONE1/14BONE1-articleInline.jpg',
#     'format': 'Normal',
#     'height': 124,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'An X-ray of a healthy human jawbone. “It is one of the most loaded bones in the human body,” one scientist said.',
#     'copyright': 'D. Roberts/Science Source'}],
#   'short_url': 'https://nyti.ms/3nPhAa4'},
#  {'section': 'health',
#   'subsection': '',
#   'title': '3 Covid-19 Trials Have Been Paused for Safety. That’s a Good Thing.',
#   'abstract': 'Experts were comforted that companies are following safety precautions. They pointed out that pauses in vaccine trials are common, but pauses in treatment trials like Eli Lilly’s are rare.',
#   'url': 'https://www.nytimes.com/2020/10/14/health/covid-clinical-trials.html',
#   'uri': 'nyt://article/3c51c998-7a7e-5b6c-94cd-69e0ba7143e4',
#   'byline': 'By Carl Zimmer',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T12:51:20-04:00',
#   'created_date': '2020-10-14T12:36:18-04:00',
#   'published_date': '2020-10-14T12:36:18-04:00',
#   'material_type_facet': '',
#   'kicker': 'Matter',
#   'des_facet': ['Clinical Trials',
#    'Drugs (Pharmaceuticals)',
#    'Coronavirus (2019-nCoV)',
#    'Vaccination and Immunization',
#    'your-feed-healthcare'],
#   'org_facet': ['AstraZeneca PLC',
#    'Eli Lilly and Company',
#    'Johnson & Johnson',
#    'Regeneron Pharmaceuticals Inc'],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/14/science/14VIRUS-TRIALPAUSE1/14VIRUS-TRIALPAUSE1-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A Johnson &amp; Johnson Phase 3 vaccine trial location in National City, Calif., on Tuesday. It was the second high-profile trial to pause this week because of safety concerns.',
#     'copyright': 'Mike Blake/Reuters'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14VIRUS-TRIALPAUSE1/14VIRUS-TRIALPAUSE1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A Johnson &amp; Johnson Phase 3 vaccine trial location in National City, Calif., on Tuesday. It was the second high-profile trial to pause this week because of safety concerns.',
#     'copyright': 'Mike Blake/Reuters'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14VIRUS-TRIALPAUSE1/14VIRUS-TRIALPAUSE1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A Johnson &amp; Johnson Phase 3 vaccine trial location in National City, Calif., on Tuesday. It was the second high-profile trial to pause this week because of safety concerns.',
#     'copyright': 'Mike Blake/Reuters'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14VIRUS-TRIALPAUSE1/14VIRUS-TRIALPAUSE1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A Johnson &amp; Johnson Phase 3 vaccine trial location in National City, Calif., on Tuesday. It was the second high-profile trial to pause this week because of safety concerns.',
#     'copyright': 'Mike Blake/Reuters'},
#    {'url': 'https://static01.nyt.com/images/2020/10/14/science/14VIRUS-TRIALPAUSE1/14VIRUS-TRIALPAUSE1-articleInline.jpg',
#     'format': 'Normal',
#     'height': 125,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A Johnson &amp; Johnson Phase 3 vaccine trial location in National City, Calif., on Tuesday. It was the second high-profile trial to pause this week because of safety concerns.',
#     'copyright': 'Mike Blake/Reuters'}],
#   'short_url': 'https://nyti.ms/3iVwSX7'},
#  {'section': 'health',
#   'subsection': '',
#   'title': 'Having Dementia Doesn’t Mean You Can’t Vote',
#   'abstract': 'Yes, you can help a cognitively impaired person participate in the election. But heed these two guidelines.',
#   'url': 'https://www.nytimes.com/2020/10/14/health/election-voting-seniors-dementia.html',
#   'uri': 'nyt://article/d044d876-1afd-5751-9e8f-8c9d7dcac5d1',
#   'byline': 'By Paula Span',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T10:31:02-04:00',
#   'created_date': '2020-10-14T10:31:02-04:00',
#   'published_date': '2020-10-14T10:31:02-04:00',
#   'material_type_facet': '',
#   'kicker': 'the new old age',
#   'des_facet': ['your-feed-science',
#    'Absentee Voting',
#    'Voter Registration and Requirements',
#    'Presidential Election of 2020',
#    "Alzheimer's Disease",
#    'Elderly',
#    'Dementia',
#    'Nursing Homes',
#    'Disabilities',
#    'Retirement Communities and Assisted Living',
#    'your-feed-health',
#    'Content Type: Service'],
#   'org_facet': [],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/15/science/15SCI-SPAN-VOTING2/15SCI-SPAN-VOTING2-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Edward Kozlowski, of Bethesda, Md., who has voted in every election in his adult life, was helped with his ballot by his daughter, Judith Kozlowski.',
#     'copyright': 'Christina Perry'},
#    {'url': 'https://static01.nyt.com/images/2020/10/15/science/15SCI-SPAN-VOTING2/15SCI-SPAN-VOTING2-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Edward Kozlowski, of Bethesda, Md., who has voted in every election in his adult life, was helped with his ballot by his daughter, Judith Kozlowski.',
#     'copyright': 'Christina Perry'},
#    {'url': 'https://static01.nyt.com/images/2020/10/15/science/15SCI-SPAN-VOTING2/15SCI-SPAN-VOTING2-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Edward Kozlowski, of Bethesda, Md., who has voted in every election in his adult life, was helped with his ballot by his daughter, Judith Kozlowski.',
#     'copyright': 'Christina Perry'},
#    {'url': 'https://static01.nyt.com/images/2020/10/15/science/15SCI-SPAN-VOTING2/15SCI-SPAN-VOTING2-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Edward Kozlowski, of Bethesda, Md., who has voted in every election in his adult life, was helped with his ballot by his daughter, Judith Kozlowski.',
#     'copyright': 'Christina Perry'},
#    {'url': 'https://static01.nyt.com/images/2020/10/15/science/15SCI-SPAN-VOTING2/15SCI-SPAN-VOTING2-articleInline.jpg',
#     'format': 'Normal',
#     'height': 126,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Edward Kozlowski, of Bethesda, Md., who has voted in every election in his adult life, was helped with his ballot by his daughter, Judith Kozlowski.',
#     'copyright': 'Christina Perry'}],
#   'short_url': 'https://nyti.ms/3jX5WYk'},
#  {'section': 'science',
#   'subsection': '',
#   'title': 'Mario Molina, 77, Dies; Sounded an Alarm on the Ozone Layer',
#   'abstract': 'He shared the Nobel Prize in Chemistry for research that showed how chemicals in hair spray and other products could cause grave environmental damage.',
#   'url': 'https://www.nytimes.com/2020/10/13/science/mario-molina-dead.html',
#   'uri': 'nyt://article/5eda54a5-c3d7-55f4-bdbc-6db17f46362f',
#   'byline': 'By John Schwartz',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T11:14:08-04:00',
#   'created_date': '2020-10-13T19:26:11-04:00',
#   'published_date': '2020-10-13T19:26:11-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Deaths (Obituaries)',
#    'Chlorofluorocarbons',
#    'Ozone',
#    'Greenhouse Gas Emissions',
#    'Global Warming',
#    'Nobel Prizes',
#    'Research'],
#   'org_facet': [],
#   'per_facet': ['Rowland, F Sherwood', 'Molina, Mario J'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/12/obituaries/12Molina1/12Molina1-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1584,
#     'width': 2000,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mario Molina spoke to reporters in 1995 after it was announced that he was one of the winners of the Nobel Prize in Chemistry for his work on climate change.',
#     'copyright': 'Elise Amendola/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/obituaries/12Molina1/12Molina1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mario Molina spoke to reporters in 1995 after it was announced that he was one of the winners of the Nobel Prize in Chemistry for his work on climate change.',
#     'copyright': 'Elise Amendola/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/obituaries/12Molina1/12Molina1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mario Molina spoke to reporters in 1995 after it was announced that he was one of the winners of the Nobel Prize in Chemistry for his work on climate change.',
#     'copyright': 'Elise Amendola/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/obituaries/12Molina1/12Molina1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mario Molina spoke to reporters in 1995 after it was announced that he was one of the winners of the Nobel Prize in Chemistry for his work on climate change.',
#     'copyright': 'Elise Amendola/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/obituaries/12Molina1/12Molina1-articleInline.jpg',
#     'format': 'Normal',
#     'height': 150,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mario Molina spoke to reporters in 1995 after it was announced that he was one of the winners of the Nobel Prize in Chemistry for his work on climate change.',
#     'copyright': 'Elise Amendola/Associated Press'}],
#   'short_url': 'https://nyti.ms/3nOfWFK'},
#  {'section': 'espanol',
#   'subsection': '',
#   'title': 'El mayor humedal tropical del mundo se ha convertido en un infierno',
#   'abstract': 'Este año, alrededor de una cuarta parte del vasto humedal el Pantanal en Brasil, uno de los lugares más biodiversos del planeta, ha sucumbido bajo las llamas de los incendios forestales que el cambio climático ha empeorado.',
#   'url': 'https://www.nytimes.com/interactive/2020/10/13/climate/pantanal-incendio-brasil.html',
#   'uri': 'nyt://interactive/3a48033a-f65f-5c0b-a61f-0b5a2d4afafe',
#   'byline': 'Por Catrin Einhorn, Maria Magdalena Arréllaga, Blacki Migliozzi and Scott Reinhard',
#   'item_type': 'Interactive',
#   'updated_date': '2020-10-13T20:18:58-04:00',
#   'created_date': '2020-10-13T19:23:54-04:00',
#   'published_date': '2020-10-13T19:23:54-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Wildfires',
#    'Wetlands',
#    'Agriculture and Farming',
#    'Animals',
#    'Environment',
#    'Indigenous People',
#    'Global Warming'],
#   'org_facet': [],
#   'per_facet': ['Bolsonaro, Jair (1955- )'],
#   'geo_facet': ['Pantanal (Brazil)', 'Amazon Jungle'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/13/us/pantanal-incendio-brasil-promo-1602628799735/pantanal-incendio-brasil-promo-1602628799735-superJumbo-v2.jpg',
#     'format': 'superJumbo',
#     'height': 1331,
#     'width': 2000,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/us/pantanal-incendio-brasil-promo-1602628799735/pantanal-incendio-brasil-promo-1602628799735-thumbStandard-v2.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/us/pantanal-incendio-brasil-promo-1602628799735/pantanal-incendio-brasil-promo-1602628799735-thumbLarge-v2.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/us/pantanal-incendio-brasil-promo-1602628799735/pantanal-incendio-brasil-promo-1602628799735-mediumThreeByTwo210-v2.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/us/pantanal-incendio-brasil-promo-1602628799735/pantanal-incendio-brasil-promo-1602628799735-articleInline-v2.jpg',
#     'format': 'Normal',
#     'height': 126,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''}],
#   'short_url': 'https://nyti.ms/2ItRpWj'},
#  {'section': 'health',
#   'subsection': '',
#   'title': 'Coronavirus Reinfections Are Real but Very, Very Rare',
#   'abstract': 'A case in Nevada has spurred new concerns that people who have recovered from the infection may still be vulnerable. That’s unlikely, experts say.',
#   'url': 'https://www.nytimes.com/2020/10/13/health/coronavirus-reinfection.html',
#   'uri': 'nyt://article/9eb3c1e8-915c-5958-991b-8546b589605d',
#   'byline': 'By Apoorva Mandavilli',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T11:51:54-04:00',
#   'created_date': '2020-10-13T18:25:29-04:00',
#   'published_date': '2020-10-13T18:25:29-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Coronavirus (2019-nCoV)',
#    'Coronavirus Risks and Safety Concerns',
#    'Disease Rates',
#    'Immune System',
#    'Vaccination and Immunization',
#    'your-feed-science'],
#   'org_facet': ['Lancet Infectious Diseases, The (Journal)'],
#   'per_facet': [],
#   'geo_facet': ['Europe', 'United States', 'Nevada'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/13/science/13VIRUS-REINFECTION/merlin_175494492_e8be6fb3-5dfe-4f3e-ac27-88fb84c4bb19-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'People waited to be tested for coronavirus at Elmhurst Hospital Center in New York in March.',
#     'copyright': 'John Minchillo/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/science/13VIRUS-REINFECTION/13VIRUS-REINFECTION-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'People waited to be tested for coronavirus at Elmhurst Hospital Center in New York in March.',
#     'copyright': 'John Minchillo/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/science/13VIRUS-REINFECTION/13VIRUS-REINFECTION-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'People waited to be tested for coronavirus at Elmhurst Hospital Center in New York in March.',
#     'copyright': 'John Minchillo/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/science/13VIRUS-REINFECTION/13VIRUS-REINFECTION-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'People waited to be tested for coronavirus at Elmhurst Hospital Center in New York in March.',
#     'copyright': 'John Minchillo/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/science/13VIRUS-REINFECTION/merlin_175494492_e8be6fb3-5dfe-4f3e-ac27-88fb84c4bb19-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'People waited to be tested for coronavirus at Elmhurst Hospital Center in New York in March.',
#     'copyright': 'John Minchillo/Associated Press'}],
#   'short_url': 'https://nyti.ms/3iTaA8p'},
#  {'section': 'health',
#   'subsection': '',
#   'title': 'Eli Lilly’s Antibody Trial Is Paused Over Potential Safety Concern',
#   'abstract': 'The drugmaker’s experimental antibody treatment is similar to the one President Trump received from Regeneron.',
#   'url': 'https://www.nytimes.com/2020/10/13/health/eli-lilly-antibody.html',
#   'uri': 'nyt://article/9ea76f15-d8de-50db-9a31-84651d0d1af2',
#   'byline': 'By Katherine J. Wu and Katie Thomas',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T10:21:52-04:00',
#   'created_date': '2020-10-13T15:56:32-04:00',
#   'published_date': '2020-10-13T15:56:32-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Clinical Trials',
#    'Drugs (Pharmaceuticals)',
#    'Coronavirus (2019-nCoV)',
#    'your-feed-healthcare'],
#   'org_facet': ['Eli Lilly and Company',
#    'Johnson & Johnson',
#    'AstraZeneca PLC'],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/13/multimedia/13virus-briefing-lilly/13virus-briefing-lilly-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1304,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“Safety is of the utmost importance to Lilly,” a spokeswoman for Eli Lilly said on Tuesday.',
#     'copyright': 'Darron Cummings/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/multimedia/13virus-briefing-lilly/13virus-briefing-lilly-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“Safety is of the utmost importance to Lilly,” a spokeswoman for Eli Lilly said on Tuesday.',
#     'copyright': 'Darron Cummings/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/multimedia/13virus-briefing-lilly/13virus-briefing-lilly-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“Safety is of the utmost importance to Lilly,” a spokeswoman for Eli Lilly said on Tuesday.',
#     'copyright': 'Darron Cummings/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/multimedia/13virus-briefing-lilly/13virus-briefing-lilly-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“Safety is of the utmost importance to Lilly,” a spokeswoman for Eli Lilly said on Tuesday.',
#     'copyright': 'Darron Cummings/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/multimedia/13virus-briefing-lilly/13virus-briefing-lilly-articleInline.jpg',
#     'format': 'Normal',
#     'height': 116,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“Safety is of the utmost importance to Lilly,” a spokeswoman for Eli Lilly said on Tuesday.',
#     'copyright': 'Darron Cummings/Associated Press'}],
#   'short_url': 'https://nyti.ms/311uLes'},
#  {'section': 'climate',
#   'subsection': '',
#   'title': 'Under Trump, Criminal Prosecutions for Pollution Dropped Sharply',
#   'abstract': 'A new report finds an “alarming” drop in prosecutions over violations of the Clean Air Act and Clean Water Act, fundamental environmental laws.',
#   'url': 'https://www.nytimes.com/2020/10/13/climate/pollution-lawsuits-trump-environment.html',
#   'uri': 'nyt://article/476e3eae-e09d-56df-9441-1a4672601165',
#   'byline': 'By John Schwartz',
#   'item_type': 'Article',
#   'updated_date': '2020-10-13T18:11:36-04:00',
#   'created_date': '2020-10-13T14:17:10-04:00',
#   'published_date': '2020-10-13T14:17:10-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Clean Water Act',
#    'United States Politics and Government',
#    'Suits and Litigation (Civil)',
#    'Environment',
#    'Fines (Penalties)'],
#   'org_facet': ['Environmental Protection Agency', 'Justice Department'],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/13/climate/13CLI-POLLUTION1/merlin_178458453_4439a4cd-5f08-4df6-a105-1f7081d6de7b-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'An emissions compliance test at the California Air Resources Board Haagen-Smit Laboratory in El Monte, Calif., in 2015. A 2017 ruling ordered Volkswagon to pay a $2.8 billion criminal fine for cheating on emissions standards tests.',
#     'copyright': 'Patrick T. Fallon/Bloomberg'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/climate/13CLI-POLLUTION1/13CLI-POLLUTION1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'An emissions compliance test at the California Air Resources Board Haagen-Smit Laboratory in El Monte, Calif., in 2015. A 2017 ruling ordered Volkswagon to pay a $2.8 billion criminal fine for cheating on emissions standards tests.',
#     'copyright': 'Patrick T. Fallon/Bloomberg'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/climate/13CLI-POLLUTION1/13CLI-POLLUTION1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'An emissions compliance test at the California Air Resources Board Haagen-Smit Laboratory in El Monte, Calif., in 2015. A 2017 ruling ordered Volkswagon to pay a $2.8 billion criminal fine for cheating on emissions standards tests.',
#     'copyright': 'Patrick T. Fallon/Bloomberg'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/climate/13CLI-POLLUTION1/13CLI-POLLUTION1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'An emissions compliance test at the California Air Resources Board Haagen-Smit Laboratory in El Monte, Calif., in 2015. A 2017 ruling ordered Volkswagon to pay a $2.8 billion criminal fine for cheating on emissions standards tests.',
#     'copyright': 'Patrick T. Fallon/Bloomberg'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/climate/13CLI-POLLUTION1/13CLI-POLLUTION1-articleInline.jpg',
#     'format': 'Normal',
#     'height': 125,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'An emissions compliance test at the California Air Resources Board Haagen-Smit Laboratory in El Monte, Calif., in 2015. A 2017 ruling ordered Volkswagon to pay a $2.8 billion criminal fine for cheating on emissions standards tests.',
#     'copyright': 'Patrick T. Fallon/Bloomberg'}],
#   'short_url': 'https://nyti.ms/33UKsFZ'},
#  {'section': 'climate',
#   'subsection': '',
#   'title': 'Trump’s ‘Frack’ Attack on Biden Seems to Be Falling Short',
#   'abstract': 'President Trump has made fracking  a "Hail Mary" attack on Joe Biden in the industrial Midwest, but  three weeks before Election Day, it does not seem to be working.',
#   'url': 'https://www.nytimes.com/2020/10/13/climate/trump-biden-fracking.html',
#   'uri': 'nyt://article/acaea8ca-4086-59c0-a5e5-f935fad02ecf',
#   'byline': 'By Lisa Friedman',
#   'item_type': 'Article',
#   'updated_date': '2020-10-13T15:28:23-04:00',
#   'created_date': '2020-10-13T11:03:48-04:00',
#   'published_date': '2020-10-13T11:03:48-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Global Warming',
#    'Environment',
#    'Greenhouse Gas Emissions',
#    'Presidential Election of 2020',
#    'United States Politics and Government',
#    'Green New Deal',
#    'Hydraulic Fracturing'],
#   'org_facet': [],
#   'per_facet': ['Biden, Joseph R Jr', 'Trump, Donald J'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/13/climate/13CLI-BIDENFRACKING1/merlin_178332417_ff00cee9-b7c2-40b0-8bed-804085ea5d12-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Joseph R. Biden Jr., the Democratic presidential nominee, campaigning in Erie, Pa., on Saturday.\xa0',
#     'copyright': 'Chang W. Lee/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/climate/13CLI-BIDENFRACKING1/13CLI-BIDENFRACKING1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Joseph R. Biden Jr., the Democratic presidential nominee, campaigning in Erie, Pa., on Saturday.\xa0',
#     'copyright': 'Chang W. Lee/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/climate/13CLI-BIDENFRACKING1/13CLI-BIDENFRACKING1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Joseph R. Biden Jr., the Democratic presidential nominee, campaigning in Erie, Pa., on Saturday.\xa0',
#     'copyright': 'Chang W. Lee/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/climate/13CLI-BIDENFRACKING1/13CLI-BIDENFRACKING1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Joseph R. Biden Jr., the Democratic presidential nominee, campaigning in Erie, Pa., on Saturday.\xa0',
#     'copyright': 'Chang W. Lee/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/climate/13CLI-BIDENFRACKING1/13CLI-BIDENFRACKING1-articleInline.jpg',
#     'format': 'Normal',
#     'height': 132,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Joseph R. Biden Jr., the Democratic presidential nominee, campaigning in Erie, Pa., on Saturday.\xa0',
#     'copyright': 'Chang W. Lee/The New York Times'}],
#   'short_url': 'https://nyti.ms/3lEFe7i'},
#  {'section': 'climate',
#   'subsection': '',
#   'title': 'The World’s Largest Tropical Wetland Has Become an Inferno',
#   'abstract': 'This year, roughly a quarter of the vast Pantanal wetland in Brazil, one of the most biodiverse places on Earth, has burned in wildfires worsened by climate change.',
#   'url': 'https://www.nytimes.com/interactive/2020/10/13/climate/pantanal-brazil-fires.html',
#   'uri': 'nyt://interactive/d88f2cee-55d9-535c-8fc7-c44259764c34',
#   'byline': 'By Catrin Einhorn, Maria Magdalena Arréllaga, Blacki Migliozzi and Scott Reinhard',
#   'item_type': 'Interactive',
#   'updated_date': '2020-10-14T19:03:04-04:00',
#   'created_date': '2020-10-13T10:12:12-04:00',
#   'published_date': '2020-10-13T10:12:12-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Wildfires',
#    'Wetlands',
#    'Agriculture and Farming',
#    'Animals',
#    'Environment',
#    'Indigenous People',
#    'Global Warming',
#    'Drought',
#    'Biodiversity'],
#   'org_facet': [],
#   'per_facet': ['Bolsonaro, Jair (1955- )'],
#   'geo_facet': ['Pantanal (Brazil)', 'Amazon Jungle'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/12/us/pantanal-brazil-fires-promo-1602539858586/pantanal-brazil-fires-promo-1602539858586-superJumbo-v5.jpg',
#     'format': 'superJumbo',
#     'height': 1331,
#     'width': 2000,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/us/pantanal-brazil-fires-promo-1602539858586/pantanal-brazil-fires-promo-1602539858586-thumbStandard-v5.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/us/pantanal-brazil-fires-promo-1602539858586/pantanal-brazil-fires-promo-1602539858586-thumbLarge-v5.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/us/pantanal-brazil-fires-promo-1602539858586/pantanal-brazil-fires-promo-1602539858586-mediumThreeByTwo210-v5.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/us/pantanal-brazil-fires-promo-1602539858586/pantanal-brazil-fires-promo-1602539858586-articleInline-v5.jpg',
#     'format': 'Normal',
#     'height': 126,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''}],
#   'short_url': 'https://nyti.ms/34LVA7a'},
#  {'section': 'science',
#   'subsection': '',
#   'title': 'How a 2nd-Grade Class Sent a Science Experiment to Space',
#   'abstract': '“Any school district now that affords football can afford spaceflight.”',
#   'url': 'https://www.nytimes.com/2020/10/13/science/blue-origin-school-experiment.html',
#   'uri': 'nyt://article/fdb8b57b-2592-52e8-8601-9c6f2b2e63d4',
#   'byline': 'By Kenneth Chang',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T06:00:17-04:00',
#   'created_date': '2020-10-13T09:53:31-04:00',
#   'published_date': '2020-10-13T09:53:31-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Education (K-12)',
#    'Private Spaceflight',
#    'Fireflies',
#    'Space and Astronomy',
#    'Science and Technology',
#    'Rocket Science and Propulsion',
#    'Research'],
#   'org_facet': ['Blue Origin'],
#   'per_facet': [],
#   'geo_facet': ['Indiana'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/09/24/science/24SCI-FIREFLIES02/merlin_177515334_f6cc968d-c1ce-4a86-b14c-0fca222a4bb4-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 800,
#     'width': 1280,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'In 2019, NASA flew eight experiment payloads on a Blue Origin flight. In 2017, second-grade scientists in Indiana were able to send their own experiment into space.',
#     'copyright': 'Blue Origin'},
#    {'url': 'https://static01.nyt.com/images/2020/09/24/science/24SCI-FIREFLIES02/24SCI-FIREFLIES02-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'In 2019, NASA flew eight experiment payloads on a Blue Origin flight. In 2017, second-grade scientists in Indiana were able to send their own experiment into space.',
#     'copyright': 'Blue Origin'},
#    {'url': 'https://static01.nyt.com/images/2020/09/24/science/24SCI-FIREFLIES02/24SCI-FIREFLIES02-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'In 2019, NASA flew eight experiment payloads on a Blue Origin flight. In 2017, second-grade scientists in Indiana were able to send their own experiment into space.',
#     'copyright': 'Blue Origin'},
#    {'url': 'https://static01.nyt.com/images/2020/09/24/science/24SCI-FIREFLIES02/24SCI-FIREFLIES02-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'In 2019, NASA flew eight experiment payloads on a Blue Origin flight. In 2017, second-grade scientists in Indiana were able to send their own experiment into space.',
#     'copyright': 'Blue Origin'},
#    {'url': 'https://static01.nyt.com/images/2020/09/24/science/24SCI-FIREFLIES02/merlin_177515334_f6cc968d-c1ce-4a86-b14c-0fca222a4bb4-articleInline.jpg',
#     'format': 'Normal',
#     'height': 119,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'In 2019, NASA flew eight experiment payloads on a Blue Origin flight. In 2017, second-grade scientists in Indiana were able to send their own experiment into space.',
#     'copyright': 'Blue Origin'}],
#   'short_url': 'https://nyti.ms/2IrhKEs'},
#  {'section': 'climate',
#   'subsection': '',
#   'title': 'Environmentalists and Dam Operators, at War for Years, Start Making Peace',
#   'abstract': 'Facing a climate crisis, environmental groups and industry agree to work together to bolster hydropower while reducing harm from dams.',
#   'url': 'https://www.nytimes.com/2020/10/13/climate/environmentalists-hydropower-dams.html',
#   'uri': 'nyt://article/d3948d4b-938d-5cd6-8968-378da0abbc85',
#   'byline': 'By Brad Plumer',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T12:15:19-04:00',
#   'created_date': '2020-10-13T06:00:07-04:00',
#   'published_date': '2020-10-13T06:00:07-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Levees and Dams',
#    'Environment',
#    'Hydroelectric Power',
#    'Alternative and Renewable Energy',
#    'Energy and Power',
#    'Global Warming'],
#   'org_facet': ['National Hydropower Assn',
#    'Natural Resources Defense Council',
#    'Nature Conservancy',
#    'American Rivers'],
#   'per_facet': [],
#   'geo_facet': ['United States'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/05/science/00CLI-HYDROPOWER01/00CLI-HYDROPOWER01-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Hoover Dam on the Colorado River, on the border between Arizona and Nevada, is one of the 2,400 hydroelectric plants that produce about seven percent of electricity in the United States.',
#     'copyright': 'David Walter Banks for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/05/science/00CLI-HYDROPOWER01/00CLI-HYDROPOWER01-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Hoover Dam on the Colorado River, on the border between Arizona and Nevada, is one of the 2,400 hydroelectric plants that produce about seven percent of electricity in the United States.',
#     'copyright': 'David Walter Banks for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/05/science/00CLI-HYDROPOWER01/00CLI-HYDROPOWER01-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Hoover Dam on the Colorado River, on the border between Arizona and Nevada, is one of the 2,400 hydroelectric plants that produce about seven percent of electricity in the United States.',
#     'copyright': 'David Walter Banks for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/05/science/00CLI-HYDROPOWER01/00CLI-HYDROPOWER01-mediumThreeByTwo210-v2.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Hoover Dam on the Colorado River, on the border between Arizona and Nevada, is one of the 2,400 hydroelectric plants that produce about seven percent of electricity in the United States.',
#     'copyright': 'David Walter Banks for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/05/science/00CLI-HYDROPOWER01/00CLI-HYDROPOWER01-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Hoover Dam on the Colorado River, on the border between Arizona and Nevada, is one of the 2,400 hydroelectric plants that produce about seven percent of electricity in the United States.',
#     'copyright': 'David Walter Banks for The New York Times'}],
#   'short_url': 'https://nyti.ms/3nJsRc3'},
#  {'section': 'business',
#   'subsection': '',
#   'title': 'Covid-19 Vaccines Are Chance at Salvation, Financial and Beyond, for Drug Makers',
#   'abstract': 'Big profits beckon for pharmaceutical companies, which are already using their work on vaccines to fight efforts in Washington to curb drug prices.',
#   'url': 'https://www.nytimes.com/2020/10/13/business/drug-companies-covid-19-vaccines.html',
#   'uri': 'nyt://article/2eaed015-1a75-5b2b-a7ff-ecc5cc53a549',
#   'byline': 'By Jesse Drucker, David Gelles and Katie Thomas',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T12:03:39-04:00',
#   'created_date': '2020-10-13T05:00:16-04:00',
#   'published_date': '2020-10-13T05:00:16-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Coronavirus (2019-nCoV)',
#    'Vaccination and Immunization',
#    'Drugs (Pharmaceuticals)',
#    'Clinical Trials'],
#   'org_facet': ['AstraZeneca PLC', 'Johnson & Johnson'],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/09/business/00Virus-Vaccines-04/merlin_177849075_24ef9e5b-39ba-430c-9010-abeb7f4cfe7d-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Representative Jody Hice, a Georgia Republican, at a House hearing last month on prescription drug costs.',
#     'copyright': 'Alex Edelman/EPA, via Shutterstock'},
#    {'url': 'https://static01.nyt.com/images/2020/10/09/business/00Virus-Vaccines-04/merlin_177849075_24ef9e5b-39ba-430c-9010-abeb7f4cfe7d-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Representative Jody Hice, a Georgia Republican, at a House hearing last month on prescription drug costs.',
#     'copyright': 'Alex Edelman/EPA, via Shutterstock'},
#    {'url': 'https://static01.nyt.com/images/2020/10/09/business/00Virus-Vaccines-04/merlin_177849075_24ef9e5b-39ba-430c-9010-abeb7f4cfe7d-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Representative Jody Hice, a Georgia Republican, at a House hearing last month on prescription drug costs.',
#     'copyright': 'Alex Edelman/EPA, via Shutterstock'},
#    {'url': 'https://static01.nyt.com/images/2020/10/09/business/00Virus-Vaccines-04/merlin_177849075_24ef9e5b-39ba-430c-9010-abeb7f4cfe7d-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Representative Jody Hice, a Georgia Republican, at a House hearing last month on prescription drug costs.',
#     'copyright': 'Alex Edelman/EPA, via Shutterstock'},
#    {'url': 'https://static01.nyt.com/images/2020/10/09/business/00Virus-Vaccines-04/merlin_177849075_24ef9e5b-39ba-430c-9010-abeb7f4cfe7d-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Representative Jody Hice, a Georgia Republican, at a House hearing last month on prescription drug costs.',
#     'copyright': 'Alex Edelman/EPA, via Shutterstock'}],
#   'short_url': 'https://nyti.ms/3lB8MCE'},
#  {'section': 'health',
#   'subsection': '',
#   'title': 'She Hunts Viral Rumors About Real Viruses',
#   'abstract': 'For Heidi Larson, the founder of the Vaccine Confidence Project, dispelling vaccine hesitancy means building trust — and avoiding the term “anti-vaxxer.”',
#   'url': 'https://www.nytimes.com/2020/10/13/health/coronavirus-vaccine-hesitancy-larson.html',
#   'uri': 'nyt://article/a38299f0-6593-5ca8-9172-2027be9ee846',
#   'byline': 'By Jenny Anderson',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T11:40:33-04:00',
#   'created_date': '2020-10-13T02:30:14-04:00',
#   'published_date': '2020-10-13T02:30:14-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Vaccination and Immunization',
#    'Coronavirus (2019-nCoV)',
#    'Rumors and Misinformation',
#    'Archaeology and Anthropology',
#    'Polls and Public Opinion',
#    'Social Media',
#    'Computers and the Internet',
#    'your-feed-science',
#    'your-feed-health'],
#   'org_facet': ['Facebook Inc', "United Nations Children's Fund"],
#   'per_facet': ['Larson, Heidi', 'Piot, Peter'],
#   'geo_facet': ['Nigeria', 'London (England)'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/08/science/00SCI-VIRUS-LARSON01/00SCI-VIRUS-LARSON01-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Heidi Larson walks to her office at the London School of Hygiene and Tropical Medicine.',
#     'copyright': 'Edu Bayer for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/08/science/00SCI-VIRUS-LARSON01/00SCI-VIRUS-LARSON01-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Heidi Larson walks to her office at the London School of Hygiene and Tropical Medicine.',
#     'copyright': 'Edu Bayer for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/08/science/00SCI-VIRUS-LARSON01/00SCI-VIRUS-LARSON01-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Heidi Larson walks to her office at the London School of Hygiene and Tropical Medicine.',
#     'copyright': 'Edu Bayer for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/08/science/00SCI-VIRUS-LARSON01/00SCI-VIRUS-LARSON01-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Heidi Larson walks to her office at the London School of Hygiene and Tropical Medicine.',
#     'copyright': 'Edu Bayer for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/08/science/00SCI-VIRUS-LARSON01/00SCI-VIRUS-LARSON01-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
# ...
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'In places like Bal Harbour, Fla., climate worries have reduced demand for high-risk coastal real estate, researchers say.',
#     'copyright': 'Rose Marie Cromwell for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/13/science/12CLI-FLORIDA01/merlin_178301409_6afa210c-ef5c-4334-9edb-874d3b3fd00f-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'In places like Bal Harbour, Fla., climate worries have reduced demand for high-risk coastal real estate, researchers say.',
#     'copyright': 'Rose Marie Cromwell for The New York Times'}],
#   'short_url': 'https://nyti.ms/34ORkE3'},
#  {'section': 'climate',
#   'subsection': '',
#   'title': 'After a Year in the Ice, the Biggest-Ever Arctic Science Mission Ends',
#   'abstract': 'The research ship Polarstern docked in Germany after nearly 13 months studying the rapidly changing region.',
#   'url': 'https://www.nytimes.com/2020/10/12/climate/mosaic-arctic-expedition-climate-change.html',
#   'uri': 'nyt://article/997b2f06-0542-5cf8-8cb8-cf75c2597901',
#   'byline': 'By Henry Fountain',
#   'item_type': 'Article',
#   'updated_date': '2020-10-13T00:08:59-04:00',
#   'created_date': '2020-10-12T05:28:00-04:00',
#   'published_date': '2020-10-12T05:28:00-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Global Warming', 'Research'],
#   'org_facet': ['Multidisciplinary drifting Observatory for the Study of Arctic Climate (MOSAiC)',
#    'Wegener, Alfred, Institute for Polar and Marine Research'],
#   'per_facet': [],
#   'geo_facet': ['Arctic Regions'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/12/world/12cli-mosaic-1sub/merlin_178391778_3c242427-f78b-4bb0-8f66-9634cce01ec9-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1333,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Polarstern, an icebreaker and research vessel, arriving on Monday at the harbor of the northern German city of Bremerhaven.\xa0',
#     'copyright': 'Patrik Stollarz/Agence France-Presse — Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/world/12cli-mosaic-1sub/12cli-mosaic-1sub-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Polarstern, an icebreaker and research vessel, arriving on Monday at the harbor of the northern German city of Bremerhaven.\xa0',
#     'copyright': 'Patrik Stollarz/Agence France-Presse — Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/world/12cli-mosaic-1sub/12cli-mosaic-1sub-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Polarstern, an icebreaker and research vessel, arriving on Monday at the harbor of the northern German city of Bremerhaven.\xa0',
#     'copyright': 'Patrik Stollarz/Agence France-Presse — Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/world/12cli-mosaic-1sub/12cli-mosaic-1sub-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Polarstern, an icebreaker and research vessel, arriving on Monday at the harbor of the northern German city of Bremerhaven.\xa0',
#     'copyright': 'Patrik Stollarz/Agence France-Presse — Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2020/10/12/world/12cli-mosaic-1sub/merlin_178391778_3c242427-f78b-4bb0-8f66-9634cce01ec9-articleInline.jpg',
#     'format': 'Normal',
#     'height': 124,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Polarstern, an icebreaker and research vessel, arriving on Monday at the harbor of the northern German city of Bremerhaven.\xa0',
#     'copyright': 'Patrik Stollarz/Agence France-Presse — Getty Images'}],
#   'short_url': 'https://nyti.ms/3lCyHtY'},
#  {'section': 'books',
#   'subsection': 'review',
#   'title': 'Black and White and Living Color',
#   'abstract': '“The Talk” and “This Is Your Brain on Stereotypes” offer two very different approaches to helping children understand and confront bias.',
#   'url': 'https://www.nytimes.com/2020/10/11/books/review/wade-hudson-cheryl-willis-hudson-the-talk-conversations-about-race-love-and-truth.html',
#   'uri': 'nyt://article/6af68b3f-7dcf-5909-9b48-8860ded518cc',
#   'byline': 'By Abby McGanney Nolan',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T02:30:02-04:00',
#   'created_date': '2020-10-11T01:40:53-04:00',
#   'published_date': '2020-10-11T01:40:53-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Books and Literature',
#    'Children and Childhood',
#    'The Talk: Conversations about Race, Love & Truth (Book)',
#    'This Is Your Brain on Stereotypes: How Science Is Tackling Unconscious Bias (Book)',
#    'Discrimination',
#    'Race and Ethnicity'],
#   'org_facet': [],
#   'per_facet': ['Hudson, Wade (Author)',
#    'Hudson, Cheryl Willis',
#    'Kyi, Tanya Lloyd',
#    'Shannon, Drew (Illustrator)'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/18/books/review/18-BKS-NOLAN-KIDS-Combo/18-BKS-NOLAN-KIDS-Combo-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1322,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/18/books/review/18-BKS-NOLAN-KIDS-Combo/18-BKS-NOLAN-KIDS-Combo-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/18/books/review/18-BKS-NOLAN-KIDS-Combo/18-BKS-NOLAN-KIDS-Combo-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/18/books/review/18-BKS-NOLAN-KIDS-Combo/18-BKS-NOLAN-KIDS-Combo-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2020/10/18/books/review/18-BKS-NOLAN-KIDS-Combo/18-BKS-NOLAN-KIDS-Combo-articleInline.jpg',
#     'format': 'Normal',
#     'height': 123,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''}],
#   'short_url': 'https://nyti.ms/3iOZRf9'},
#  {'section': 'at-home',
#   'subsection': '',
#   'title': 'Rest Better With Light Exercises',
#   'abstract': 'Stretching and meditative movement like yoga before bed can improve the quality of your sleep and the amount you sleep. Here is a short and calming routine of 11 stretches and exercises.',
#   'url': 'https://www.nytimes.com/2020/10/10/at-home/exercises-for-better-sleep.html',
#   'uri': 'nyt://article/8049bb4d-b28b-5cb5-8e17-c0c607d45e7a',
#   'byline': 'By Kelly DiNardo',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T17:44:24-04:00',
#   'created_date': '2020-10-10T23:41:09-04:00',
#   'published_date': '2020-10-10T23:41:09-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Quarantine (Life and Culture)',
#    'Back (Human Body Part)',
#    'Legs',
#    'Knees',
#    'Anxiety and Stress',
#    'Yoga',
#    'Sleep',
#    'Neck',
#    'Exercise',
#    'Content Type: Service'],
#   'org_facet': [],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/11/multimedia/11ah-catcow/11ah-catcow-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 495,
#     'width': 530,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Brown Bird Design'},
#    {'url': 'https://static01.nyt.com/images/2020/10/11/multimedia/11ah-catcow/11ah-catcow-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Brown Bird Design'},
#    {'url': 'https://static01.nyt.com/images/2020/10/11/multimedia/11ah-catcow/11ah-catcow-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Brown Bird Design'},
#    {'url': 'https://static01.nyt.com/images/2020/10/11/multimedia/11ah-catcow/11ah-catcow-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Brown Bird Design'},
#    {'url': 'https://static01.nyt.com/images/2020/10/11/multimedia/11ah-catcow/11ah-catcow-articleInline.jpg',
#     'format': 'Normal',
#     'height': 177,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Brown Bird Design'}],
#   'short_url': 'https://nyti.ms/34Kd5or'},
#  {'section': 'health',
#   'subsection': '',
#   'title': 'Nevada Revokes Halt on Rapid Antigen Testing in Nursing Homes',
#   'abstract': 'The reversal came just hours after the federal government threatened the state, calling the prohibition on the tests “illegal.”',
#   'url': 'https://www.nytimes.com/2020/10/10/health/covid-nevada-testing-nursing-homes.html',
#   'uri': 'nyt://article/58b2644e-3850-56c3-87aa-f956408c109a',
#   'byline': 'By Katherine J. Wu',
#   'item_type': 'Article',
#   'updated_date': '2020-10-11T16:34:04-04:00',
#   'created_date': '2020-10-10T16:35:23-04:00',
#   'published_date': '2020-10-10T16:35:23-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Coronavirus (2019-nCoV)',
#    'Tests (Medical)',
#    'Nursing Homes',
#    'Disease Rates',
#    'your-feed-science',
#    'your-feed-health',
#    'your-feed-healthcare'],
#   'org_facet': ['Becton Dickinson & Co',
#    'Quidel Corporation',
#    'Health and Human Services Department'],
#   'per_facet': ['Giroir, Brett P'],
#   'geo_facet': ['Nevada'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/10/multimedia/10virus-nevada-test-sub/merlin_176718288_823b67ea-0ca4-4b05-8808-89697a9011ae-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1478,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Nevada’s reversal came after receipt of a threatening letter from the federal government.',
#     'copyright': 'Farooq Khan/EPA, via Shutterstock'},
#    {'url': 'https://static01.nyt.com/images/2020/10/10/multimedia/10virus-nevada-test-sub/merlin_176718288_823b67ea-0ca4-4b05-8808-89697a9011ae-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Nevada’s reversal came after receipt of a threatening letter from the federal government.',
#     'copyright': 'Farooq Khan/EPA, via Shutterstock'},
#    {'url': 'https://static01.nyt.com/images/2020/10/10/multimedia/10virus-nevada-test-sub/merlin_176718288_823b67ea-0ca4-4b05-8808-89697a9011ae-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Nevada’s reversal came after receipt of a threatening letter from the federal government.',
#     'copyright': 'Farooq Khan/EPA, via Shutterstock'},
#    {'url': 'https://static01.nyt.com/images/2020/10/10/multimedia/10virus-nevada-test-sub/merlin_176718288_823b67ea-0ca4-4b05-8808-89697a9011ae-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Nevada’s reversal came after receipt of a threatening letter from the federal government.',
#     'copyright': 'Farooq Khan/EPA, via Shutterstock'},
#    {'url': 'https://static01.nyt.com/images/2020/10/10/multimedia/10virus-nevada-test-sub/merlin_176718288_823b67ea-0ca4-4b05-8808-89697a9011ae-articleInline.jpg',
#     'format': 'Normal',
#     'height': 137,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Nevada’s reversal came after receipt of a threatening letter from the federal government.',
#     'copyright': 'Farooq Khan/EPA, via Shutterstock'}],
#   'short_url': 'https://nyti.ms/2SWyuWh'},
#  {'section': 'health',
#   'subsection': '',
#   'title': 'Extra Pounds May Raise Risk of Severe Covid-19',
#   'abstract': 'Even people who aren’t obese may be more likely to become seriously ill when infected with the coronavirus, the C.D.C. said.',
#   'url': 'https://www.nytimes.com/2020/10/10/health/coronavirus-obesity-weight.html',
#   'uri': 'nyt://article/9515e35f-a503-562c-b67b-4958b8937959',
#   'byline': 'By Roni Caryn Rabin',
#   'item_type': 'Article',
#   'updated_date': '2020-10-14T08:44:24-04:00',
#   'created_date': '2020-10-10T15:54:07-04:00',
#   'published_date': '2020-10-10T15:54:07-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Coronavirus (2019-nCoV)',
#    'Weight',
#    'Obesity',
#    'Fat Tissue',
#    'Diet and Nutrition',
#    'Disease Rates',
#    'Coronavirus Risks and Safety Concerns',
#    'your-feed-science'],
#   'org_facet': ['Centers for Disease Control and Prevention',
#    'International Journal of Obesity'],
#   'per_facet': [],
#   'geo_facet': ['United States', 'Great Britain'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2020/10/10/science/10VIRUS-OVERWEIGHT01/10VIRUS-OVERWEIGHT01-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'By the new calculus, more than two-thirds of Americans may be at risk of severe Covid-19 if infected with the coronavirus. Exercise may be protective.',
#     'copyright': 'Brittainy Newman for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/10/science/10VIRUS-OVERWEIGHT01/10VIRUS-OVERWEIGHT01-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'By the new calculus, more than two-thirds of Americans may be at risk of severe Covid-19 if infected with the coronavirus. Exercise may be protective.',
#     'copyright': 'Brittainy Newman for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/10/science/10VIRUS-OVERWEIGHT01/10VIRUS-OVERWEIGHT01-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'By the new calculus, more than two-thirds of Americans may be at risk of severe Covid-19 if infected with the coronavirus. Exercise may be protective.',
#     'copyright': 'Brittainy Newman for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/10/science/10VIRUS-OVERWEIGHT01/10VIRUS-OVERWEIGHT01-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'By the new calculus, more than two-thirds of Americans may be at risk of severe Covid-19 if infected with the coronavirus. Exercise may be protective.',
#     'copyright': 'Brittainy Newman for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2020/10/10/science/10VIRUS-OVERWEIGHT01/10VIRUS-OVERWEIGHT01-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'By the new calculus, more than two-thirds of Americans may be at risk of severe Covid-19 if infected with the coronavirus. Exercise may be protective.',
#     'copyright': 'Brittainy Newman for The New York Times'}],
#   'short_url': 'https://nyti.ms/3jRhoEM'}]

# %%
import datetime

articles = nyt.article_search(
    query = "Covid19",
    results = 10,
    dates = {
        "begin": datetime.datetime(2020, 3, 1),
        "end": datetime.datetime(2020, 10, 12)
    },
    options = {
        "sort": "oldest",
        "sources": [
            "New York Times",
            "AP",
            "Reuters",
            "International Herald Tribune"
        ],
        "news_desk": [
            "Politics"
        ],
        "type_of_material": [
            "News Analysis"
        ]
    }
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-54-879b1670f9f7> in <module>
#      20         ],
#      21         "type_of_material": [
# ---> 22             "News Analysis"
#      23         ]
#      24     }
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/pynytimes/api.py in article_search(self, query, dates, options, results)
#     479             # Load data and raise error if there's and error status
#     480             res = self.session.get(url, params=params)
# --> 481             res.raise_for_status()
#     482
#     483             # Parse results and append them to results list
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#     943     def close(self):
#
# HTTPError: 401 Client Error: Unauthorized for url: http://api.nytimes.com/svc/search/v2/articlesearch.json?sort=oldest&sources=New+York+Times&sources=AP&sources=Reuters&sources=International+Herald+Tribune&fq=news_desk%3A%28%22Politics%22%29+AND+type_of_material%3A%28%22News+Analysis%22%29&q=Covid19&begin_date=20200301&end_date=20201012&api-key=AGTGevw2BdpxCUBRjEyFC0ymAVDHVA0e&page=0

# %%
import pandas as pd
from nytimesarticle import articleAPI

# %%
nyt_api_key='AGTGevw2BdpxCUBRjEyFC0ymAVDHVA0e'
api=articleAPI(nyt_api_key)
api

# %%
import os
import json
import time
import requests
import datetime
import dateutil
import pandas as pd
from dateutil.relativedelta import relativedelta

# %%
end = datetime.date.today()
start = end - relativedelta(months=7)

# %%
months_in_range = [x.split(' ') for x in pd.date_range(start, end, freq='MS').strftime("%Y %-m").tolist()]

# %%
def send_request(date):
    '''Sends a request to the NYT Archive API for given date.'''
    base_url = 'https://api.nytimes.com/svc/archive/v1/'
    url = base_url + '/' + date[0] + '/' + date[1] + '.json?api-key=' + 'AGTGevw2BdpxCUBRjEyFC0ymAVDHVA0e'
    response = requests.get(url).json()
    time.sleep(6)
    return response


def is_valid(article, date):
    '''An article is only worth checking if it is in range, and has a headline.'''
    is_in_range = date > start and date < end
    has_headline = type(article['headline']) == dict and 'main' in article['headline'].keys()
    return is_in_range and has_headline


def parse_response(response):
    '''Parses and returns response as pandas data frame.'''
    data = {'headline': [],  
        'date': [], 
        'doc_type': [],
        'material_type': [],
        'section': [],
        'keywords': []}
    
    articles = response['response']['docs'] 
    for article in articles: # For each article, make sure it falls within our date range
        date = dateutil.parser.parse(article['pub_date']).date()
        if is_valid(article, date):
            data['date'].append(date)
            data['headline'].append(article['headline']['main']) 
            if 'section' in article:
                data['section'].append(article['section_name'])
            else:
                data['section'].append(None)
            data['doc_type'].append(article['document_type'])
            if 'type_of_material' in article: 
                data['material_type'].append(article['type_of_material'])
            else:
                data['material_type'].append(None)
            keywords = [keyword['value'] for keyword in article['keywords'] if keyword['name'] == 'subject']
            data['keywords'].append(keywords)
    return pd.DataFrame(data) 


def get_data(dates):
    '''Sends and parses request/response to/from NYT Archive API for given dates.'''
    total = 0
    print('Date range: ' + str(dates[0]) + ' to ' + str(dates[-1]))
    if not os.path.exists('headlines'):
        os.mkdir('headlines')
    for date in dates:
        response = send_request(date)
        df = parse_response(response)
        total += len(df)
        df.to_csv('headlines/' + date[0] + '-' + date[1] + '.csv', index=False)
        print('Saving headlines/' + date[0] + '-' + date[1] + '.csv...')
    print('Number of articles collected: ' + str(total))

# %%
get_data(months_in_range)
# Out:
# Date range: ['2020', '4'] to ['2020', '10']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-c4c17a031262> in <module>
# ----> 1 get_data(months_in_range)
#
# <ipython-input-75-b8d372f37761> in get_data(dates)
#      51         os.mkdir('headlines')
#      52     for date in dates:
# ---> 53         response = send_request(date)
#      54         df = parse_response(response)
#      55         total += len(df)
#
# <ipython-input-75-b8d372f37761> in send_request(date)
#       2     '''Sends a request to the NYT Archive API for given date.'''
#       3     base_url = 'https://api.nytimes.com/svc/archive/v1/'
# ----> 4     url = base_url + '/' + date[0] + '/' + date[1] + '.json?api-key=' + AGTGevw2BdpxCUBRjEyFC0ymAVDHVA0e
#       5     response = requests.get(url).json()
#       6     time.sleep(6)
#
# NameError: name 'AGTGevw2BdpxCUBRjEyFC0ymAVDHVA0e' is not defined

# %%
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-ab0153f39f33> in <module>
# ----> 1 response
#
# NameError: name 'response' is not defined
